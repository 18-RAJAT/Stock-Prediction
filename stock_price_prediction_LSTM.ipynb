# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("MSFT.csv")

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1990-01-02    0.605903    0.616319    0.598090    0.616319    0.447268
# 1     1990-01-03    0.621528    0.626736    0.614583    0.619792    0.449788
# 2     1990-01-04    0.619792    0.638889    0.616319    0.638021    0.463017
# 3     1990-01-05    0.635417    0.638889    0.621528    0.622396    0.451678
# 4     1990-01-08    0.621528    0.631944    0.614583    0.631944    0.458607
# ...          ...         ...         ...         ...         ...         ...
# 7329  2019-02-04  102.870003  105.800003  102.769997  105.739998  105.739998
# 7330  2019-02-05  106.059998  107.269997  105.959999  107.220001  107.220001
# 7331  2019-02-06  107.000000  107.000000  105.529999  106.029999  106.029999
# 7332  2019-02-07  105.190002  105.589996  104.290001  105.269997  105.269997
# 7333  2019-02-08  104.389999  105.779999  104.260002  105.669998  105.669998
#
#          Volume
# 0      53033600
# ...

# %%
df.head(5)
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  1990-01-02  0.605903  0.616319  0.598090  0.616319   0.447268   53033600
# 1  1990-01-03  0.621528  0.626736  0.614583  0.619792   0.449788  113772800
# 2  1990-01-04  0.619792  0.638889  0.616319  0.638021   0.463017  125740800
# 3  1990-01-05  0.635417  0.638889  0.621528  0.622396   0.451678   69564800
# 4  1990-01-08  0.621528  0.631944  0.614583  0.631944   0.458607   58982400

# %%
df.tail(3)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 7331  2019-02-06  107.000000  107.000000  105.529999  106.029999  106.029999
# 7332  2019-02-07  105.190002  105.589996  104.290001  105.269997  105.269997
# 7333  2019-02-08  104.389999  105.779999  104.260002  105.669998  105.669998
#
#         Volume
# 7331  20609800
# 7332  29760700
# 7333  21456000

# %%
df=pd.read_csv("MSFT.csv",na_values=['null'],index_col='Date',parse_dates=True,infer_datetime_format=True)

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1990-01-02    0.605903    0.616319    0.598090    0.616319    0.447268
# 1990-01-03    0.621528    0.626736    0.614583    0.619792    0.449788
# 1990-01-04    0.619792    0.638889    0.616319    0.638021    0.463017
# 1990-01-05    0.635417    0.638889    0.621528    0.622396    0.451678
# 1990-01-08    0.621528    0.631944    0.614583    0.631944    0.458607
# ...                ...         ...         ...         ...         ...
# 2019-02-04  102.870003  105.800003  102.769997  105.739998  105.739998
# 2019-02-05  106.059998  107.269997  105.959999  107.220001  107.220001
# 2019-02-06  107.000000  107.000000  105.529999  106.029999  106.029999
# 2019-02-07  105.190002  105.589996  104.290001  105.269997  105.269997
# 2019-02-08  104.389999  105.779999  104.260002  105.669998  105.669998
#
#                Volume
# Date
# 1990-01-02   53033600
# 1990-01-03  113772800
# 1990-01-04  125740800
# ...

# %%
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 1990-01-02  0.605903  0.616319  0.598090  0.616319   0.447268   53033600
# 1990-01-03  0.621528  0.626736  0.614583  0.619792   0.449788  113772800
# 1990-01-04  0.619792  0.638889  0.616319  0.638021   0.463017  125740800
# 1990-01-05  0.635417  0.638889  0.621528  0.622396   0.451678   69564800
# 1990-01-08  0.621528  0.631944  0.614583  0.631944   0.458607   58982400

# %%
df.shape
# Out:
# (7334, 6)

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  7334.000000  7334.000000  7334.000000  7334.000000  7334.000000
# mean     28.578362    28.891892    28.261203    28.582426    24.008891
# std      22.279033    22.476021    22.054379    22.275692    21.941225
# min       0.591146     0.604167     0.583333     0.598090     0.434039
# 25%      12.457031    12.595703    12.261719    12.488281     9.062849
# 50%      26.980000    27.235000    26.730000    26.990000    20.431164
# 75%      34.716562    35.099998    34.250000    34.687500    26.993589
# max     115.419998   116.180000   114.930000   115.610001   115.112709
#
#              Volume
# count  7.334000e+03
# mean   6.022760e+07
# std    3.400345e+07
# min    3.705600e+06
# 25%    3.821840e+07
# 50%    5.429885e+07
# 75%    7.367888e+07
# max    7.645040e+08

# %%
df['Adj Close'].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df.isnull().values.any()
# Out:
# False

# %%
df['Low'].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df['Open'].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df['Volume'].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df.head(10)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 1990-01-02  0.605903  0.616319  0.598090  0.616319   0.447268   53033600
# 1990-01-03  0.621528  0.626736  0.614583  0.619792   0.449788  113772800
# 1990-01-04  0.619792  0.638889  0.616319  0.638021   0.463017  125740800
# 1990-01-05  0.635417  0.638889  0.621528  0.622396   0.451678   69564800
# 1990-01-08  0.621528  0.631944  0.614583  0.631944   0.458607   58982400
# 1990-01-09  0.631944  0.638889  0.626736  0.630208   0.457347   70300800
# 1990-01-10  0.625000  0.633681  0.611979  0.612847   0.444748  103766400
# 1990-01-11  0.616319  0.621528  0.590278  0.600694   0.435929   95772800
# 1990-01-12  0.591146  0.605903  0.583333  0.598090   0.434039  148908800
# 1990-01-15  0.595486  0.604167  0.592014  0.598090   0.434039   62467200

# %%
df.tail(10)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-28  106.260002  106.480003  104.660004  105.080002  105.080002
# 2019-01-29  104.879997  104.970001  102.169998  102.940002  102.940002
# 2019-01-30  104.620003  106.379997  104.330002  106.379997  106.379997
# 2019-01-31  103.800003  105.220001  103.180000  104.430000  104.430000
# 2019-02-01  103.779999  104.099998  102.349998  102.779999  102.779999
# 2019-02-04  102.870003  105.800003  102.769997  105.739998  105.739998
# 2019-02-05  106.059998  107.269997  105.959999  107.220001  107.220001
# 2019-02-06  107.000000  107.000000  105.529999  106.029999  106.029999
# 2019-02-07  105.190002  105.589996  104.290001  105.269997  105.269997
# 2019-02-08  104.389999  105.779999  104.260002  105.669998  105.669998
#
#               Volume
# Date
# 2019-01-28  29476700
# 2019-01-29  31490500
# 2019-01-30  49471900
# 2019-01-31  55636400
# 2019-02-01  35535700
# 2019-02-04  31315100
# ...

# %%
df['Close'].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %% [markdown]
# # Correction Analysis

# %%
x=df.drop(['Adj Close'],axis=1)
x=x.drop(['Close'],axis=1)

# %%
x.corrwith(df['Adj Close']).plot.bar(
    figsize=(20,10),title="Correction Analysis",fontsize=17,
    rot=90,grid=True)
# Out:
# <AxesSubplot: title={'center': 'Correction Analysis'}>

# %%
value=df['Low'].dtype

# %%
value
# Out:
# dtype('float64')

# %%
mini=df['Low'].min()

# %%
mini
# Out:
# 0.583333

# %%
maxi=df['High'].max()

# %%
maxi
# Out:
# 116.18

# %%
df=df.abs()

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1990-01-02    0.605903    0.616319    0.598090    0.616319    0.447268
# 1990-01-03    0.621528    0.626736    0.614583    0.619792    0.449788
# 1990-01-04    0.619792    0.638889    0.616319    0.638021    0.463017
# 1990-01-05    0.635417    0.638889    0.621528    0.622396    0.451678
# 1990-01-08    0.621528    0.631944    0.614583    0.631944    0.458607
# ...                ...         ...         ...         ...         ...
# 2019-02-04  102.870003  105.800003  102.769997  105.739998  105.739998
# 2019-02-05  106.059998  107.269997  105.959999  107.220001  107.220001
# 2019-02-06  107.000000  107.000000  105.529999  106.029999  106.029999
# 2019-02-07  105.190002  105.589996  104.290001  105.269997  105.269997
# 2019-02-08  104.389999  105.779999  104.260002  105.669998  105.669998
#
#                Volume
# Date
# 1990-01-02   53033600
# 1990-01-03  113772800
# 1990-01-04  125740800
# ...

# %%
Sum=df.sum()

# %%
Sum
# Out:
# Open         2.095937e+05
# High         2.118931e+05
# Low          2.072677e+05
# Close        2.096235e+05
# Adj Close    1.760812e+05
# Volume       4.417092e+11
# dtype: float64

# %%
division=df.div(2)

# %%
division
# Out:
#                  Open       High        Low      Close  Adj Close      Volume
# Date
# 1990-01-02   0.302951   0.308159   0.299045   0.308159   0.223634  26516800.0
# 1990-01-03   0.310764   0.313368   0.307291   0.309896   0.224894  56886400.0
# 1990-01-04   0.309896   0.319445   0.308159   0.319010   0.231509  62870400.0
# 1990-01-05   0.317709   0.319445   0.310764   0.311198   0.225839  34782400.0
# 1990-01-08   0.310764   0.315972   0.307291   0.315972   0.229303  29491200.0
# ...               ...        ...        ...        ...        ...         ...
# 2019-02-04  51.435001  52.900002  51.384999  52.869999  52.869999  15657550.0
# 2019-02-05  53.029999  53.634999  52.979999  53.610000  53.610000  13662700.0
# 2019-02-06  53.500000  53.500000  52.765000  53.015000  53.015000  10304900.0
# 2019-02-07  52.595001  52.794998  52.145001  52.634999  52.634999  14880350.0
# 2019-02-08  52.195000  52.890000  52.130001  52.834999  52.834999  10728000.0
#
# [7334 rows x 6 columns]

# %%
test=df

#Target Column
target_adj_close=pd.DataFrame(test['Adj Close'])
display(test.head(5))
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 1990-01-02  0.605903  0.616319  0.598090  0.616319   0.447268   53033600
# 1990-01-03  0.621528  0.626736  0.614583  0.619792   0.449788  113772800
# 1990-01-04  0.619792  0.638889  0.616319  0.638021   0.463017  125740800
# 1990-01-05  0.635417  0.638889  0.621528  0.622396   0.451678   69564800
# 1990-01-08  0.621528  0.631944  0.614583  0.631944   0.458607   58982400

# %%
# Selecting Featuring Columns
featureColumns=['open','high','low','volume']

# %%
featureColumns
# Out:
# ['open', 'high', 'low', 'volume']

# %%
df=df[:]

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1990-01-02    0.605903    0.616319    0.598090    0.616319    0.447268
# 1990-01-03    0.621528    0.626736    0.614583    0.619792    0.449788
# 1990-01-04    0.619792    0.638889    0.616319    0.638021    0.463017
# 1990-01-05    0.635417    0.638889    0.621528    0.622396    0.451678
# 1990-01-08    0.621528    0.631944    0.614583    0.631944    0.458607
# ...                ...         ...         ...         ...         ...
# 2019-02-04  102.870003  105.800003  102.769997  105.739998  105.739998
# 2019-02-05  106.059998  107.269997  105.959999  107.220001  107.220001
# 2019-02-06  107.000000  107.000000  105.529999  106.029999  106.029999
# 2019-02-07  105.190002  105.589996  104.290001  105.269997  105.269997
# 2019-02-08  104.389999  105.779999  104.260002  105.669998  105.669998
#
#                Volume
# Date
# 1990-01-02   53033600
# 1990-01-03  113772800
# 1990-01-04  125740800
# ...
